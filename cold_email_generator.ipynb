# %%
from dotenv import load_dotenv
import os
load_dotenv()

from langchain_groq import ChatGroq

llm = ChatGroq(
    
    temperature=0,
    model_name="llama-3.3-70b-versatile",
    groq_api_key=os.getenv("GROQ_API_KEY")
)

# %%
response = llm.invoke("what is module and class in python?")
print(response.content)
# Out:
# **Modules and Classes in Python**
# ...
#
# ### Modules
#
# In Python, a **module** is a file that contains a collection of related functions, classes, and variables. Modules are used to organize code, promote code reuse, and make it easier to maintain and extend large programs.
#
# A module can be thought of as a container that holds a set of related definitions, such as:
#
# * Functions
# * Classes
# * Variables
# * Constants
#
# Modules can be imported into other Python programs, allowing you to use the definitions they contain.
#
# **Example:**
# ```python
# # mymodule.py
# def greet(name):
#     print(f"Hello, {name}!")
#
# def add(x, y):
#     return x + y
# ```
#
# ```python
# # main.py
# import mymodule
#
# mymodule.greet("John")  # Output: Hello, John!
# result = mymodule.add(2, 3)
# print(result)  # Output: 5
# ```
#
# ### Classes
#
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader

# %%
loader = WebBaseLoader("https://careers.nike.com/software-engineer-ii-itc/job/R-85702")

# %%
page_data = loader.load().pop().page_content

# %%
print(page_data)
# Out:
# Software Engineer II,ITC
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to main content
# Open Virtual Assistant
#
#
#
#
#
#
#
#
#
#
# Home
#
#
# Career Areas
#
#
# Total Rewards
#
#
# Life@Nike
#
#
# Purpose
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
#
# Select a Language
#
#   Deutsch
#   English
#   Español (España)
#   Español (América Latina)
#   Français
#   Italiano
#   Nederlands
#   Polski
#   Tiếng Việt
#   Türkçe
#   简体中文
#   繁體中文
#   עִברִית
#   한국어
#   日本語
#
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Close Menu
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
# Chat
#
#
#
#
#
#
#                                 Home
#
#
#
#
#                                 Career Areas
#
#
#
#
#                                 Total Rewards
#
#
#
#
#                                 Life@Nike
#
#
#
#
#                                 Purpose
#
#
#
#
#
#
#
#
#
#
#
# Jordan Careers
#
#
#
#
#
#
#
# Converse Careers
#
#
#
#
#
#
#
#
#
#
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data})
print(res.content)
# Out:
# ```json
# {
#   "role": "Software Engineer II, ITC",
#   "experience": "2-4 years",
#   "skills": [
#     "Cloud Engineering",
#     "AWS",
#     "Azure",
#     "Google Cloud",
#     "Kubernetes",
#     "Control Plane architecture",
#     "Custom Resource Definitions (CRDs)",
#     "Python",
#     "GoLang",
#     "Java",
#     "JavaScript",
#     "Graphana",
#     "Prometheus",
#     "Splunk",
#     "Cortex",
#     "Thanos"
#   ],
#   "description": "We are looking for a Software Engineer II as part of our Cloud Platform Engineering team at Nike. The ideal candidate will be bringing deep technical expertise in Cloud Engineering to solve complex engineering problems to enable Nike’s pursuit to deliver state of the art Enterprise Cloud infrastructure to run Nike’s business and support our athletes."
# }
# ```

# %%
type(res.content)
# Out:
# str

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# {'role': 'Software Engineer II, ITC',
#  'experience': '2-4 years',
#  'skills': ['Cloud Engineering',
#   'AWS',
#   'Azure',
#   'Google Cloud',
#   'Kubernetes',
#   'Control Plane architecture',
#   'Custom Resource Definitions (CRDs)',
#   'Python',
#   'GoLang',
#   'Java',
#   'JavaScript',
#   'Graphana',
#   'Prometheus',
#   'Splunk',
#   'Cortex',
#   'Thanos'],
#  'description': 'We are looking for a Software Engineer II as part of our Cloud Platform Engineering team at Nike. The ideal candidate will be bringing deep technical expertise in Cloud Engineering to solve complex engineering problems to enable Nike’s pursuit to deliver state of the art Enterprise Cloud infrastructure to run Nike’s business and support our athletes.'}

# %%
type(json_res)
# Out:
# dict

# %%
import pandas as pd
data_frame = pd.read_csv("url_portfolio.csv")
data_frame
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# ...

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in data_frame.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])

# %%
json_res["skills"]
# Out:
# ['Cloud Engineering',
#  'AWS',
#  'Azure',
#  'Google Cloud',
#  'Kubernetes',
#  'Control Plane architecture',
#  'Custom Resource Definitions (CRDs)',
#  'Python',
#  'GoLang',
#  'Java',
#  'JavaScript',
#  'Graphana',
#  'Prometheus',
#  'Splunk',
#  'Cortex',
#  'Thanos']

# %%
links = collection.query(query_texts=json_res['skills'], n_results=2).get('metadatas', [])
links
# Out:
# [[{'links': 'https://example.com/devops-portfolio'},
#   {'links': 'https://example.com/xamarin-portfolio'}],
#  [{'links': 'https://example.com/ios-ar-portfolio'},
#   {'links': 'https://example.com/wordpress-portfolio'}],
#  [{'links': 'https://example.com/xamarin-portfolio'},
#   {'links': 'https://example.com/angular-portfolio'}],
#  [{'links': 'https://example.com/xamarin-portfolio'},
#   {'links': 'https://example.com/kotlin-android-portfolio'}],
#  [{'links': 'https://example.com/devops-portfolio'},
#   {'links': 'https://example.com/kotlin-backend-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/ios-ar-portfolio'}],
#  [{'links': 'https://example.com/kotlin-backend-portfolio'},
#   {'links': 'https://example.com/java-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/python-portfolio'}],
#  [{'links': 'https://example.com/ios-ar-portfolio'},
# ...

# %%
email_prompt = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Achyuth, a business development executive at XYZ company. XYZ is an AI & Software Service company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of XYZ
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase XYZ's portfolio: {link_list}
        Remember you are Achyuth, BDE at XYZ. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = email_prompt | llm
res = chain_email.invoke({"job_description": str(json_res), "link_list": links})
print(res.content)
# Out:
# Subject: Expert Cloud Engineering Solutions for Nike's Enterprise Cloud Infrastructure
#
# Dear Hiring Manager,
#
# I came across the job description for a Software Engineer II, ITC at Nike, and I'm excited to introduce XYZ's capabilities in cloud engineering, which align perfectly with your requirements. As a business development executive at XYZ, I'd like to highlight our expertise in delivering tailored solutions that foster scalability, process optimization, cost reduction, and heightened overall efficiency.
#
# Our team has extensive experience in cloud engineering, with proficiency in AWS, Azure, Google Cloud, Kubernetes, Control Plane architecture, Custom Resource Definitions (CRDs), and other relevant technologies. We've empowered numerous enterprises with our automated tools, ensuring seamless integration of business processes.
#
# I'd like to draw your attention to our relevant portfolio:
#
# * https://example.com/devops-portfolio (DevOps portfolio)
# ...
